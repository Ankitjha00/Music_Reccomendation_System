# %%
import pandas as pd

# %%
df = pd.read_csv("spotify_millsongdata.csv")

# %%
df.head(5)
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.tail(5)
# Out:
#              artist           song  \
# 57645  Ziggy Marley  Good Old Days
# 57646  Ziggy Marley  Hand To Mouth
# 57647          Zwan   Come With Me
# 57648          Zwan         Desire
# 57649          Zwan      Heartsong
#
#                                               link  \
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# 57646  /z/ziggy+marley/hand+to+mouth_20531167.html
# 57647           /z/zwan/come+with+me_20148981.html
# 57648                 /z/zwan/desire_20148986.html
# 57649              /z/zwan/heartsong_20148991.html
#
#                                                     text
# 57645  Irie days come on play  \r\nLet the angels fly...
# 57646  Power to the workers  \r\nMore power  \r\nPowe...
# 57647  all you need  \r\nis something i'll believe  \...
# 57648  northern star  \r\nam i frightened  \r\nwhere ...
# 57649  come in  \r\nmake yourself at home  \r\ni'm a ...

# %%
df.shape
# Out:
# (57650, 4)

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
df=df.sample(5000).drop('link', axis=1).reset_index(drop=True)

# %%
df.head(10)
# Out:
#                artist                           song  \
# 0       Irving Berlin                When I Lost You
# 1             Incubus                     I Miss You
# 2                NOFX                     Door Nails
# 3      Modern Talking   Love Don't Live Here Anymore
# 4  Kris Kristofferson        Someone Loves You Honey
# 5         Iron Maiden                 Rainbow's Gold
# 6         Cheap Trick                      The Flame
# 7       One Direction                   Lost In Life
# 8            Fastball  All I Was Looking For Was You
# 9             Alabama       The Star Spangled Banner
#
#                                                 text
# 0  (musical intro)  \r\nI lost the sunshine and r...
# 1  To see you when I wake up  \r\nIs a gift I did...
# 2  These two shots are for Derrick  \r\nFor Rifle...
# 3  (Hold me darling, you know that I really, real...
# 4  I want to share your life every minute every d...
# 5  In the heat of the morning  \r\nWhen your day ...
# 6  Another night slowly closes in and I feel so l...
# 7  She's seventeen,  \r\nAnd gets to thinking,  \...
# 8  When I was a boy  \r\nI could not stand the si...
# 9  Oh, say, can you see, by the dawn's early ligh...

# %%
df['text'][0]
# Out:
# '(musical intro)  \r\nI lost the sunshine and roses, I lost the heavens of blue,  \r\nI lost the beautiful rainbow, I lost the morning dew.  \r\nI lost the angel who gave me summer, the whole winter too.  \r\nI lost the gladness that turned into sadness,  \r\nWhen I lost you.  \r\n(musical interlude)  \r\nAnd I lost the angel who gave me summer, the whole winter too.  \r\nI lost the gladness that turned into sadness,  \r\nWhen I lost you.\r\n\r\n'

# %%
df.shape
# Out:
# (5000, 3)

# %% [markdown]
# Text Cleaning/Text Preprocessing

# %%
df['text']= df['text'].str.lower().replace(r'^\w\s', ' ').replace(r'\n', ' ', regex = True)

# %%
df
# Out:
#                   artist                             song  \
# 0          Irving Berlin                  When I Lost You
# 1                Incubus                       I Miss You
# 2                   NOFX                       Door Nails
# 3         Modern Talking     Love Don't Live Here Anymore
# 4     Kris Kristofferson          Someone Loves You Honey
# ...                  ...                              ...
# 4995      Zac Brown Band            As She's Walking Away
# 4996           Radiohead                      Killer Cars
# 4997         Dean Martin                     Candy Kisses
# 4998             Ramones        Here Today, Gone Tomorrow
# 4999            Children  The Bear Went Over The Mountain
#
#                                                    text
# 0     (musical intro)  \r i lost the sunshine and ro...
# 1     to see you when i wake up  \r is a gift i didn...
# 2     these two shots are for derrick  \r for rifle,...
# 3     (hold me darling, you know that i really, real...
# 4     i want to share your life every minute every d...
# ...                                                 ...
# 4995  we never spoke a word  \r but every thought sh...
# 4996  too hard on the brakes again  \r what if these...
# 4997  candy kisses wrapped in paper  \r mean more to...
# 4998  oh oh oh,  \r oh oh oh,i love ya x2  \r i do,i...
# 4999  the bear went over the mountain,  \r the bear ...
#
# [5000 rows x 3 columns]

# %%
df.tail(5)
# Out:
#               artist                             song  \
# 4995  Zac Brown Band            As She's Walking Away
# 4996       Radiohead                      Killer Cars
# 4997     Dean Martin                     Candy Kisses
# 4998         Ramones        Here Today, Gone Tomorrow
# 4999        Children  The Bear Went Over The Mountain
#
#                                                    text
# 4995  we never spoke a word  \r but every thought sh...
# 4996  too hard on the brakes again  \r what if these...
# 4997  candy kisses wrapped in paper  \r mean more to...
# 4998  oh oh oh,  \r oh oh oh,i love ya x2  \r i do,i...
# 4999  the bear went over the mountain,  \r the bear ...

# %%
import nltk
from nltk.stem.porter import PorterStemmer

# %%
stemmer=PorterStemmer()

# %%
def token(txt):
    token = nltk.word_tokenize(txt)
    a = [stemmer.stem(w) for w in token]
    return " ".join(a)

# %%
token("you are beautiful, beauty")
# Out:
# 'you are beauti , beauti'

# %%
df['text'].apply(lambda x: token(x))
# Out:
# 0       ( music intro ) i lost the sunshin and rose , ...
# 1       to see you when i wake up is a gift i did n't ...
# 2       these two shot are for derrick for rifl , not ...
# 3       ( hold me darl , you know that i realli , real...
# 4       i want to share your life everi minut everi da...
#                               ...
# 4995    we never spoke a word but everi thought she ha...
# 4996    too hard on the brake again what if these brak...
# 4997    candi kiss wrap in paper mean more to you than...
# 4998    oh oh oh , oh oh oh , i love ya x2 i do , i do...
# 4999    the bear went over the mountain , the bear wen...
# Name: text, Length: 5000, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfid=TfidfVectorizer(analyzer='word', stop_words='english')

# %%
matrix=tfid.fit_transform(df['text'])

# %%
similer=cosine_similarity(matrix)

# %%
similer[1]
# Out:
# array([0.        , 1.        , 0.0054408 , ..., 0.        , 0.00830858,
#        0.        ], shape=(5000,))

# %%
df[df['song']=="Here Today, Gone Tomorrow"].index[0]
# Out:
# np.int64(4998)

# %%
def recommender(song_name):
    idx=df[df['song']==song_name].index[0]
    distance = sorted(list(enumerate(similer[idx])), reverse=True, key= lambda x:x[1])
    song = []
    for s_id in distance[1:21]:
        song.append(df.iloc[s_id[0]].song)
    return song

# %%
recommender("Here Today, Gone Tomorrow")
# Out:
# ['Gypsy',
#  'Here Comes The Hammer',
#  "Sweet Child O' Mine",
#  'Blind Love',
#  'My Head Sounds Like That',
#  'Glory And Gore',
#  'Just One Time',
#  'Tangled Up In Plaid',
#  'Mary Ann',
#  '2:10 Train',
#  'Oh Woman',
#  'One Last Time',
#  'Belly Full',
#  "I Ain't Goin' Down To The Well No More",
#  "I'll Never Give You Up",
#  'This Time',
#  'Hiciste',
#  'Fire Bomb',
#  'Back On Earth',
#  'Careless Love']

# %%
import pickle
pickle.dump(df, open("df","wb"))

# %%
pickle.dump(similer, open("similarity","wb"))
